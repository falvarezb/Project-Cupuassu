797,430,229,8968,422,116,3393,7986,366,21494,25813,21581,1010,21806,21499,497,6178,21487,13055,13037,21,44,88,202,3965,143,91,48495,2441,488,77,194,2217,298,25832,2830,21588,1159,2996,29422,29704,55623,54839,625,37,482,37,17786,433,25,9258,9457,267,103,272,70,61,6079,29885,1605,44,10,6,8,417,428,17662,233,280,65,4090,9967,20079,27890,27264,1071,9,3225,5740,6,0,58,26,39882,59938,304,16469,16433,186,227,24,693,708,7528,0,83,310,63,10,51286,26911,26961,9299,33520,639,636,27134,10498,10368,311,10,41,82,9,0,1573,1,3,234,1,2664,2671,3,2,90,2630,246,245,1126,964,1574,1577,1584,2,2793,245,12,11,6,14483,6554,6555,6573,6498,2891,15943,7804,3370,36386,172,764,331,254,309,78,77,24,243,284,40,3785,1914,20844,6679,119,694,694,8089,7410,245,3956,4040,338,5712,35700,20010,71,27662,238,26998,19,174,1,0,4541,4588,1,15,31977,9646,22243,5094,59450,199,6331,40127,601,9,34600,443,66,441,104,104,6318,1600,62,3878,6259,310,1023,204,380,358,2448,3,1,5535,46974,50433,145,5,5951,1159,1170,5,1130,5,1,48,5612,16326,247,702,1013,1,4,2,4702,4553,3594,3080,4723,4709,7470,1427,4660,368,7997,7977,40289,218,1634,833,11386,12916,276,3891,3885,1,168,4097,11553,69,47065,71,16,527,197,299,199,14850,1283,520,17,1761,195,471,12,150,3156,3161,17,503,161,250,15,17157,17147,81,22,158,24,154,410,34,7813,2,1194,2292,3330,6401,2156,1606,4495,57896,136,10753,33320,88,15498,25023,5007,75,73,21635,55092,59672,684,760,5900,93,9939,57,3055,1636,120,179,929,11416,398,58,685,128,313,8340,8383,321,12142,1127,191,17,61])

# %%
times.size
# Out:
# 897

# %%
stats.describe(times)
# Out:
# DescribeResult(nobs=897, minmax=(0, 59938), mean=8920.384615384615, variance=211897095.3240041, skewness=1.9502291240704148, kurtosis=2.815153999234915)

# %%
np.percentile(times, [5,10,25,50,75,90,95]).astype(int)
## 50% of the results in less than 2 secs
## 90% of the results in less than 32 secs
# Out:
# array([   10,    35,   225,  1657,  9939, 31523, 47741])

# %%
np.std(times)
# Out:
# 14548.569231307865

# %%
plt.hist(times, bins='auto', histtype='bar')
plt.title("Computation times")
plt.xlabel('time (ms)')
# Out:
# Text(0.5, 0, 'time (ms)')

# %% [markdown]
# ## Analysis of solution production rate

# %%
import pandas as pd

# %%
df = pd.read_csv(fileName, header=None, names=["minute", "numberOfPaths"])

# %%
df.head()
# Out:
#    minute  numberOfPaths
# 0       2              0
# 1       4              0
# 2       6              4
# 3       7              5
# 4       8              7

# %%
df.plot(x='minute', y='numberOfPaths')

# %%
df['numberOfPathsAccummulated'] = 0

# %%
df.head()
# Out:
#    minute  numberOfPaths  numberOfPathsAccummulated
# 0       2              0                          0
# 1       4              0                          0
# 2       6              4                          0
# 3       7              5                          0
# 4       8              7                          0

# %%
#df.drop('numberOfPathsAccummulated', axis=1, inplace=True)

# %%
df.loc[0,'numberOfPathsAccummulated'] = df.loc[0, 'numberOfPaths']

# %%
for i in range(1, len(df)):
    df.loc[i,'numberOfPathsAccummulated'] = df.loc[i, 'numberOfPaths'] + df.loc[i-1, 'numberOfPathsAccummulated']

# %%
df.plot(x='minute', y='numberOfPathsAccummulated')
